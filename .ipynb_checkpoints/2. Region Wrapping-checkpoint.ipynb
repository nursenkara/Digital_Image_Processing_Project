# %%
import cv2
import matplotlib.pyplot as plt
import numpy

# %%
imgpath = 'dog.png'
img = cv2.imread(imgpath)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
img_1_1 = plt.imshow(img[0:50,0:50]) #1.satır 1.sütun

# %%
img_2_1 = plt.imshow(img[50:100,0:50]) #2.satır 1.sütun

# %%
img_1_2 = plt.imshow(img[0:50,50:100]) #1.satır 2.sütun

# %%
img_2_2 = plt.imshow(img[50:100,50:100])  #2.satır 2.sütun

# %%
import cv2

# %%
cv2.imwrite("img_1_1.png", img[0:50,0:50])
# Out:
# True

# %%
cv2.imwrite("img_1_2.png", img[0:50,50:100])
# Out:
# True

# %%
cv2.imwrite("img_2_1.png", img[50:100,0:50])
# Out:
# True

# %%
cv2.imwrite("img_2_2.png", img[50:100,50:100])
# Out:
# True

# %%
verticalAppendedImg = numpy.vstack((img,img))

# %%
img_1_1 = cv2.imread('img_1_1.png')

# %%
img_1_2 = cv2.imread('img_1_2.png')

# %%
img_2_1 = cv2.imread('img_2_1.png')

# %%
img_2_2 = cv2.imread('img_2_2.png')

# %%
import numpy as np

# %%
import cv2

# %%
horizantalAppendedImg = np.hstack((img_2_2,img_2_1))

# %%
plt.imshow(horizantalAppendedImg)

# %%
horizantalAppendedImg2 = np.hstack((img_1_2,img_1_1))

# %%
plt.imshow(horizantalAppendedImg2)

# %%
verticalAppendedImg = np.vstack((horizantalAppendedImg,horizantalAppendedImg2))

# %%
plt.imshow(verticalAppendedImg)
