# %% [markdown]
# ## Filters

# %%
def filters(image_path,filter_name):
    image = cv2.imread(image_path)
    if filter_name == 'mean filter':
         # reads the image
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) # convert to HSV
        figure_size = 9 # the dimension of the x and y axis of the kernal.
        new_image = cv2.blur(image,(figure_size, figure_size))
        plt.figure(figsize=(11,6))
        plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_HSV2RGB)),plt.title('Original')
        plt.xticks([]), plt.yticks([])
        plt.subplot(122), plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB)),plt.title('Mean filter')
        plt.xticks([]), plt.yticks([])
        plt.show()    
    elif filter_name == "gaussian filter":
        figure_size = 9
        new_image = cv2.GaussianBlur(image, (figure_size, figure_size),0)
        plt.figure(figsize=(11,6))
        plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_HSV2RGB)),plt.title('Original')
        plt.xticks([]), plt.yticks([])
        plt.subplot(122), plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB)),plt.title('Gaussian Filter')
        plt.xticks([]), plt.yticks([])
        plt.show()
    elif filter_name == "median filter":
        figure_size = 9
        new_image = cv2.medianBlur(image, figure_size)
        plt.figure(figsize=(11,6))
        plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_HSV2RGB)),plt.title('Original')
        plt.xticks([]), plt.yticks([])
        plt.subplot(122), plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB)),plt.title('Median Filter')
        plt.xticks([]), plt.yticks([])
        plt.show()
    elif filter_name == "unsharp filter":
        image = Image.fromarray(image.astype('uint8'))
        new_image = image.filter(ImageFilter.UnsharpMask(radius=2, percent=150))
        plt.subplot(121),plt.imshow(image, cmap = 'gray')
        plt.title('Input Image'), plt.xticks([]), plt.yticks([])
        plt.subplot(122),plt.imshow(new_image, cmap = 'gray')
        plt.title('Unsharp Filter'), plt.xticks([]), plt.yticks([])
        plt.show()
    else:
        print("Enter one of the 4 filter types: mean filter, gaussian filter, median filter, unsharp filter")

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline

# %%
filters('kameraman.jpeg','mean filter')

# %%
filters('nature2.jpg','mean filter')

# %%
filters('kameraman.jpeg','gaussian filter')

# %%
filters('nature2.jpg','gaussian filter')

# %%
filters('nature3.jpg','gaussian filter')

# %%
filters('kameraman.jpeg','median filter')

# %%
filters('kameraman.jpeg','unsharp filter')

# %%
filters('Lenna.jpg','unsharp filter')
